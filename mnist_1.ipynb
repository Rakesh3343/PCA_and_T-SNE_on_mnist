# %% [markdown]
# ### In this file we are loading the images from file and converting into array.
# ### flattening the array.
# ### after converting all the images into flattened arrays, constructing a dataframe along with the class label
# ### after this storing the df into a csv file.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import os.path

# %%
a=plt.imread(r"C:\Users\rakes\Downloads\mnist_data\5\img_0.png")#used to read image from file to an array

# %%
plt.imshow(a)

# %%
a.shape
# Out:
# (28, 28, 4)

# %%
len(a[:,:,1].flatten())
# Out:
# 784

# %%
os.listdir(r"C:\Users\rakes\Downloads\mnist_data\5")#to get list of all the files in directory
# Out:
# ['img_0.png',
#  'img_1.png',
#  'img_10.png',
#  'img_100.png',
#  'img_1000.png',
#  'img_1001.png',
#  'img_1002.png',
#  'img_1003.png',
#  'img_1004.png',
#  'img_1005.png',
#  'img_1006.png',
#  'img_1007.png',
#  'img_1008.png',
#  'img_1009.png',
#  'img_101.png',
#  'img_1010.png',
#  'img_1011.png',
#  'img_1012.png',
#  'img_1013.png',
#  'img_1014.png',
#  'img_1015.png',
#  'img_1016.png',
#  'img_1017.png',
#  'img_1018.png',
#  'img_1019.png',
#  'img_102.png',
#  'img_1020.png',
#  'img_1021.png',
#  'img_1022.png',
#  'img_1023.png',
#  'img_1024.png',
#  'img_1025.png',
#  'img_1026.png',
#  'img_1027.png',
#  'img_1028.png',
#  'img_1029.png',
#  'img_103.png',
#  'img_1030.png',
#  'img_1031.png',
#  'img_1032.png',
#  'img_1033.png',
#  'img_1034.png',
#  'img_1035.png',
#  'img_1036.png',
#  'img_1037.png',
#  'img_1038.png',
#  'img_1039.png',
#  'img_104.png',
#  'img_1040.png',
#  'img_1041.png',
#  'img_1042.png',
#  'img_1043.png',
#  'img_1044.png',
# ...

# %%
d=[]
for i in range(len(os.listdir(r"C:\Users\rakes\Downloads\mnist_data\0"))):
    img=plt.imread(r"C:\Users\rakes\Downloads\mnist_data\0\img_{}.png".format(i))
    d.append(img[:,:,1].flatten())
df0=pd.DataFrame(d)
df0['target']=0

# %%
d=[]
for i in range(len(os.listdir(r"C:\Users\rakes\Downloads\mnist_data\1"))):
    img=plt.imread(r"C:\Users\rakes\Downloads\mnist_data\1\img_{}.png".format(i))
    d.append(img[:,:,1].flatten())
df1=pd.DataFrame(d)
df1['target']=1

# %%
d=[]
for i in range(len(os.listdir(r"C:\Users\rakes\Downloads\mnist_data\2"))):
    img=plt.imread(r"C:\Users\rakes\Downloads\mnist_data\2\img_{}.png".format(i))
    d.append(img[:,:,1].flatten())
df2=pd.DataFrame(d)
df2['target']=2

# %%
d=[]
for i in range(len(os.listdir(r"C:\Users\rakes\Downloads\mnist_data\3"))):
    img=plt.imread(r"C:\Users\rakes\Downloads\mnist_data\3\img_{}.png".format(i))
    d.append(img[:,:,1].flatten())
df3=pd.DataFrame(d)
df3['target']=3

# %%
d=[]
for i in range(len(os.listdir(r"C:\Users\rakes\Downloads\mnist_data\4"))):
    img=plt.imread(r"C:\Users\rakes\Downloads\mnist_data\4\img_{}.png".format(i))
    d.append(img[:,:,1].flatten())
df4=pd.DataFrame(d)
df4['target']=4

# %%
d=[]
for i in range(len(os.listdir(r"C:\Users\rakes\Downloads\mnist_data\5"))):
    img=plt.imread(r"C:\Users\rakes\Downloads\mnist_data\5\img_{}.png".format(i))
    d.append(img[:,:,1].flatten())
df5=pd.DataFrame(d)
df5['target']=5

# %%
d=[]
for i in range(len(os.listdir(r"C:\Users\rakes\Downloads\mnist_data\6"))):
    img=plt.imread(r"C:\Users\rakes\Downloads\mnist_data\6\img_{}.png".format(i))
    d.append(img[:,:,1].flatten())
df6=pd.DataFrame(d)
df6['target']=6

# %%
d=[]
for i in range(len(os.listdir(r"C:\Users\rakes\Downloads\mnist_data\7"))):
    img=plt.imread(r"C:\Users\rakes\Downloads\mnist_data\7\img_{}.png".format(i))
    d.append(img[:,:,1].flatten())
df7=pd.DataFrame(d)
df7['target']=7

# %%
d=[]
for i in range(len(os.listdir(r"C:\Users\rakes\Downloads\mnist_data\8"))):
    img=plt.imread(r"C:\Users\rakes\Downloads\mnist_data\8\img_{}.png".format(i))
    d.append(img[:,:,1].flatten())
df8=pd.DataFrame(d)
df8['target']=8

# %%
d=[]
for i in range(len(os.listdir(r"C:\Users\rakes\Downloads\mnist_data\9"))):
    img=plt.imread(r"C:\Users\rakes\Downloads\mnist_data\9\img_{}.png".format(i))
    d.append(img[:,:,1].flatten())
df9=pd.DataFrame(d)
df9['target']=9

# %%
df=pd.concat([df0,df1,df2,df3,df4,df5,df6,df7,df8,df9],ignore_index=True)

# %%
df
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 1      0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 2      0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 3      0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 4      0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# ...         ...       ...       ...       ...       ...       ...       ...
# 41995  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 41996  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 41997  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 41998  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 41999  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
#
# ...
